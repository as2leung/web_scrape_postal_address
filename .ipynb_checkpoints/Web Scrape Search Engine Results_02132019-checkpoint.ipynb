# %% [markdown]
# # Web scrape of search engine for Post Office Address
#
# ### *Andrew Leung - Feb 02, 2019*
#
# ## Libraries

# %%
from bs4 import BeautifulSoup
import os
import pandas as pd
import requests as requests

#extension for BeautifulSoup - Code highlighting - install this if needed: pip install "ipython-beautifulsoup[bs4,notebook]"
# %load_ext soup
configure_ipython_beautifulsoup(show_html=True, 
                                show_css=False, 
                                show_js=False)
# Out:
# Monkey patch BeautifulSoup with custom rendering
# See `configure_ipython_beautifulsoup?` for configuration information
# Push 'BeautifulSoup' from 'bs4' into current context
# Push 'urlopen' from 'urllib.request' into current context
# Push 'p' shortcut into current context
# Push 'requests' into current context

# %% [markdown]
# ## URL of search results for Canada Post

# %%
#for one page example
url = 'https://www.canadapost.ca/cpotools/apps/fpo/personal/findPostOfficeList?lat=43.8004476&lng=-79.27473520000001'

response = requests.get(url)
print(response.text[:500])
# Out:
# <!DOCTYPE html >
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
#     <head>
#
#         <meta name="msvalidate.01" content="1AC9A4E083D8F5E10E160861745E4E0F" />
#         <meta name="y_key" content="36a5b4f0d2c3995c" />
#             <meta http-equiv="Content-Type" content="application/xhtml+xml, text/xml, text/html; charset=utf-8" />
#             <meta http-equiv="content-language" content="en-CA" />
#             <title>Canada Post - Find a Post Office - Results List</title>
#     <meta http-equiv="

# %% [markdown]
# ### Examine full html input

# %%
#print with .prettify() function for tabs
html_soup = BeautifulSoup(response.text,'html.parser')
print(html_soup.prettify())
# Out:
# <!DOCTYPE html >
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="1AC9A4E083D8F5E10E160861745E4E0F" name="msvalidate.01"/>
#   <meta content="36a5b4f0d2c3995c" name="y_key"/>
#   <meta content="application/xhtml+xml, text/xml, text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="en-CA" http-equiv="content-language"/>
#   <title>
#    Canada Post - Find a Post Office - Results List
#   </title>
#   <meta content="post office, personal, postal outlet, post office Canada, find a post office, locate a post office, post office finder, locator, locations, hours, hours of operation, postal outlet, postal outlets, post office locations" http-equiv="keywords"/>
#   <meta content="Find a post office near you using our online tool. Enter your address or postal code and get nearby post offices, outlets, maps and hours." http-equiv="description"/>
#   <meta content="Canada Post" name="categories"/>
#   <meta content="Post office locator, find nearest post office and post office hours" name="pta"/>
#   <meta content="minimum-scale=1.0, maximum-scale=1.0, width=device-width, user-scalable=no" name="viewport"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/cpotools/apps/fpo/personal/findPostOffice" rel="canonical"/>
#   <link href="/cpotools/mc/assets/images/structure/cpo.ico" rel="shortcut icon" type="image/x-icon"/>
#   <script src="//assets.adobedtm.com/8555ef77443acd85ab4eb6b187cf7ed7fe0f79eb/satelliteLib-f2fc6f00da802a0747b6ffed3c12e3931bfca496.js">
#    <!--
#
# //-->
#   </script>
#   <script>
#    <!--
#
# 			digitalData={
#   page:{
#          pageInfo:{
# 			 audience: ("personal" == 'business' ? "business" : "common"),
# 			 language: "en",
# 			 domain: document.location.host,
# 			 destinationURL: document.location.href,
# 			 destinationQueryString: document.location.search
# 		 },
#          category:{},
#          attributes: {
# 			channel:{
# 				site: document.location.host
# 			},
# 			externalCampaignID: "",
# 			internalCampaignID: "",
# 		    language: "en",
# 			internalSearch: {
# 				term: ""
# 			}
# 		},
#   },
#   event:[{
#          eventInfo:{}
#   }],
#   product:[{
#          productInfo:{}
#   }],
#   cart:{},
#   transaction:{
#          item:[{
#                productInfo:{},
#                price:{}
#          }],
#          profile:{
#                address:{}
#          },
#          total:{},
#          attributes:{}
#   },
#   user:[{
#          profile:[{
#                profileInfo:{},
#                attributes:{
#                       profileFAN:{}
#                }
#          }]
#   }]
# };
#
# //-->
#   </script>
#   <link href="/web/assets/css/foundation5/normalize.css" rel="stylesheet"/>
#   <link href="/web/assets/css/foundation5/foundation.min.css" rel="stylesheet"/>
#   <link href="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.3/themes/smoothness/jquery-ui.css" rel="stylesheet"/>
#   <link href="/web/assets/css/responsive.css" rel="stylesheet" type="text/css"/>
#   <link href="/web/assets/css/vpo.css" rel="stylesheet" type="text/css"/>
#   <link href="/cwc/components/assets/styles/cwc.css" rel="stylesheet" type="text/css"/>
#   <link href="/web/assets/css/slick_slider.css" rel="stylesheet" type="text/css"/>
#   <link href="/cpotools/mc/ui/css/extendstyles.css" rel="stylesheet" type="text/css"/>
#   <link href="/cpotools/mc/ui/css/tony.css" rel="stylesheet" type="text/css"/>
#   <link href="/cpotools/mc/ui/css/aaron.css" rel="stylesheet" type="text/css"/>
#   <link href="/cpotools/mc/ui/css/kirk.css" rel="stylesheet" type="text/css"/>
#   <link href="/cpotools/mc/ui/css/donald.css" rel="stylesheet" type="text/css"/>
#   <link href="/cpotools/mc/ui/css/michael.css" rel="stylesheet" type="text/css"/>
#   <!-- <link rel="stylesheet" type="text/css" href="/cpotools/mc/ui/css/2008_plus_styles.css" /> -->
#   <link href="/cpotools/mc/ui/css/cp_print.css" media="print" rel="stylesheet" type="text/css"/>
#   <link href="/cpotools/mc/ui/css/jquery.autocomplete.css" rel="stylesheet" type="text/css"/>
#   <style>
#    <!--
#
#
#
# -->
#   </style>
#   <link href="/mc/ui/css/kirk.css"/>
#   <!--[if lt IE 9]><link rel="stylesheet" href="/web/assets/css/ie8-styles.css"/><![endif]-->
#   <link href="https://fonts.googleapis.com/css?family=Roboto:400|Roboto:100|Roboto:100italic|Roboto:300|Roboto:300italic|Roboto:400italic|Roboto:500|Roboto:500italic|Roboto:700|Roboto:700italic|Roboto:900|Roboto:900italic" rel="stylesheet" type="text/css"/>
#   <script language="javascript" type="text/javascript">
#    <!--
#
#     // Global JS Vars - used in javascript functions
#     var GLOBALOBJ = new Object();
#     GLOBALOBJ.locale = "en";
#     GLOBALOBJ.style = 'STANDARD';
#     GLOBALOBJ.contextPath = "/cpotools";
#     GLOBALOBJ.baseSecuredApplicationUrl = "";
#
# //-->
#   </script>
#   <script src="/web/assets/js/foundation5/vendor/modernizr.js">
#    <!--
#
# //-->
#   </script>
#   <script src="/web/assets/js/foundation5/vendor/jquery.js">
#    <!--
#
# //-->
#   </script>
#   <script src="/cwc/components/assets/scripts/cwc.js" type="text/javascript">
#    <!--
#
# //-->
#   </script>
#   <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.3/jquery-ui.min.js" type="text/javascript">
#    <!--
#
# //-->
#   </script>
#   <script src="/cpotools/mc/ui/js/selector.js" type="text/javascript">
#    <!--
#
# //-->
#   </script>
#   <script src="/cpotools/mc/ui/js/jquery-cookie.js" type="text/javascript">
#    <!--
#
# //-->
#   </script>
#   <script src="/cpotools/mc/ui/js/function.js" type="text/javascript">
#    <!--
#
# //-->
#   </script>
#   <script src="/cpotools/mc/ui/js/search_autocomplete.js" type="text/javascript">
#    <!--
#
# //-->
#   </script>
#   <script src="/web/assets/js/jCarousel.min.js" type="text/javascript">
#    <!--
#
# //-->
#   </script>
#   <script src="/cpotools/mc/ui/js/google-dfp.js" type="text/javascript">
#    <!--
#
# //-->
#   </script>
#   <script type="text/javascript">
#    <!--
#
#       var inDash = "fpo";
#
# //-->
#   </script>
#   <script type="text/javascript">
#    <!--
#
#          var adops_lang = "en";
#          var adops_switch = "fpo";
#          var adops_test = "";
#      var adops_pageid = "D00017";
#
# //-->
#   </script>
#   <script src="/web/assets/js/purl.js" type="text/javascript">
#    <!--
#
# //-->
#   </script>
#   <script src="/cpotools/mc/ui/js/adops_ts.js" type="text/javascript">
#    <!--
#
# //-->
#   </script>
#   <script src="/cpo/mc/ui/js/cpo.js" type="text/javascript">
#    <!--
#
# //-->
#   </script>
#   <script id="mapScript" language="javascript" type="text/javascript">
#    <!--
# //<![CDATA[
# 			document.write('<scr' + 'ipt type="text/javascript" src="' + document.location.protocol + '//maps.googleapis.com/maps/api/js?v=3.7&sensor=false&language=' + 'en' + '&client=gme-innovapost1"></scr' + 'ipt>');
# 			//]]>
#
# //-->
#   </script>
#   <script src="/cpotools/mc/ui/js/analytics/analyticsManager-min.js" type="text/javascript">
#    <!--
#
# //-->
#   </script>
#   <script src="/cpotools/mc/ui/js/google/gmaps.js" type="text/javascript">
#    <!--
#
# //-->
#   </script>
#   <script type="text/javascript">
#    <!--
#
# 			$().ready(function()
# 			{
# 				loadLocation();
# 				document.getElementById("g_address").focus();
# 				$("#g_address").keyup(function(event){
# 					if(event.keyCode == 13){
# 						$("#findPostOffice").click();
# 					}
# 				});
#
# 				// Your location text
# 				var xResults = $("#g_address").val();
# 				$('#location-results .address').html(xResults);
# 			});
#
# 			// RQ9702
# 			function goToMap() {
# 				var value = gmapLocation.get("location");
# 				window.location='/cpotools/apps/fpo/personal/findPostOffice?location='+value;
# 			}
#
# 			// Web Analytics
#             analyticsData.pageID = 'postOfficeListResult';
#
#
# //-->
#   </script>
#   <!-- SMART BANNERS:  -->
#   <meta content="Canada Post Corporation" name="author"/>
#   <meta content="app-id=394391577" name="apple-itunes-app"/>
#   <meta content="app-id=com.canadapost.android" name="google-play-app"/>
#   <link href="/web/assets/css/jquery.smartbanner.css" rel="stylesheet" type="text/css"/>
#   <script src="/web/assets/js/jquery.smartbanner.js" type="text/javascript">
#    <!--
#
# //-->
#   </script>
#   <script type="text/javascript">
#    <!--
#
# 		 $(function () {
#
# 		 	var language = "en";
#
# 		 	if(language == "en"){
# 		 		$.smartbanner({
# 		 		  title: "Canada Post Corporation",
# 		 		  author: "Canada Post",
# 		 		  price: 'FREE',
# 		 		  button: 'View',
# 		 		  scale: 'auto',
# 		 		  speedIn: 300,
# 		 		  speedOut: 400,
# 		 		  daysHidden: 0,
# 		 		  daysReminder: 0,
# 		 		  hideOnInstall: false,
# 		 		  layer: false,
# 		 		  force: null,
# 		 		  iOSUniversalApp: true,
# 		 		  appendToSelector: 'body'
# 		 		})
# 		 	}else{
# 		 		$.smartbanner({
# 		 		  title: "Société canadienne des postes",
# 		 		  author: "Postes Canada",
# 		 		  price: 'GRATUIT',
# 		 		  button: 'Afficher',
# 		 		  inAppStore: 'À partir de la boutique d\'applications',
# 		 		  inGooglePlay: 'Dans Google Play',
# 		 		  scale: 'auto',
# 		 		  speedIn: 300,
# 		 		  speedOut: 400,
# 		 		  daysHidden: 0,
# 		 		  daysReminder: 0,
# 		 		  hideOnInstall: false,
# 		 		  layer: false,
# 		 		  force: null,
# 		 		  iOSUniversalApp: true,
# 		 		  appendToSelector: 'body'
# 		 		})
#
# 		 	}
#
# 			if($("#topSiteMessageWrapper").length == 0) {
# 		 		$('#header').css('top','0');
# 			}
# 	 });
#
#
#
#
# //-->
#   </script>
#   <!-- END OF SMART BANNERS:	 -->
#   <!-- Twitter Code Start -->
#   <script type="text/javascript">
#    <!--
#
#       !function (e, t, n, s, u, a) {
#         e.twq || (s = e.twq = function () {
#           var _s;
#
#           s.exe ? (_s = s).exe.apply(_s, arguments) : s.queue.push(arguments);
#         }, s.version = '1.1', s.queue = [], u = t.createElement(n), u.async = !0, u.src = '//static.ads-twitter.com/uwt.js', a = t.getElementsByTagName(n)[0], a.parentNode.insertBefore(u, a));
#       }(window, document, 'script', 'https://static.ads-twitter.com/uwt.js');
#       // Insert Twitter Pixel ID and Standard Event data below
#       twq('init', 'ny0qm');
#       twq('track', 'PageView');
#
# //-->
#   </script>
#   <!-- Twitter Code End  -->
#   <!-- Facebook Pixel Code -->
#   <script type="text/javascript">
#    <!--
#
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#       if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#       n.queue=[];t=b.createElement(e);t.async=!0;
#       t.src=v;s=b.getElementsByTagName(e)[0];
#       s.parentNode.insertBefore(t,s)}(window,document,'script',
#         'https://connect.facebook.net/en_US/fbevents.js');
#       fbq('init', '786303741550354');
#       fbq('track', 'PageView');
#
# //-->
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=786303741550354&amp;ev=PageView&amp;noscript=1" width="1"/>
#   </noscript>
#   <!-- End Facebook Pixel Code -->
#  </head>
#  <!--[if IE 8]><body class="lt-ie9 en true wide"><![endif]-->
#  <!--[if IE 9]><body class="lt-ie10 en true wide"><![endif]-->
#  <!--[if gt IE 9]><!-->
#  <body class="en true wide">
#   <!--<![endif]-->
#   <!--BEGIN QUALTRICS SITE INTERCEPT-->
#   <script type="text/javascript">
#    <!--
#
# //<![CDATA[
# (function(){var g=function(e,h,f,g){
# this.get=function(a){for(var a=a+"=",c=document.cookie.split(";"),b=0,e=c.length;b<e;b++){for(var d=c[b];" "==d.charAt(0);)d=d.substring(1,d.length);if(0==d.indexOf(a))return d.substring(a.length,d.length)}return null};
# this.set=function(a,c){var b="",b=new Date;b.setTime(b.getTime()+6048E5);b="; expires="+b.toGMTString();document.cookie=a+"="+c+b+"; path=/; "};
# this.check=function(){var a=this.get(f);if(a)a=a.split(":");else if(100!=e)"v"==h&&(e=Math.random()>=e/100?0:100),a=[h,e,0],this.set(f,a.join(":"));else return!0;var c=a[1];if(100==c)return!0;switch(a[0]){case "v":return!1;case "r":return c=a[2]%Math.floor(100/c),a[2]++,this.set(f,a.join(":")),!c}return!0};
# this.go=function(){if(this.check()){var a=document.createElement("script");a.type="text/javascript";a.src=g+ "&t=" + (new Date()).getTime();document.body&&document.body.appendChild(a)}};
# this.start=function(){var a=this;window.addEventListener?window.addEventListener("load",function(){a.go()},!1):window.attachEvent&&window.attachEvent("onload",function(){a.go()})}};
# try{(new g(100,"r","QSI_S_ZN_0xleIR6sWSZaNY9","https://zn0xleir6swszany9-canadapostdigital.siteintercept.qualtrics.com/WRSiteInterceptEngine/?Q_ZID=ZN_0xleIR6sWSZaNY9&Q_LOC="+encodeURIComponent(window.location.href))).start()}catch(i){}})();
# //]]>
#
# //-->
#   </script>
#   <div id="ZN_0xleIR6sWSZaNY9">
#    <!--DO NOT REMOVE-CONTENTS PLACED HERE-->
#   </div>
#   <!--END SITE INTERCEPT-->
#   <div class="" data-offcanvas="data-offcanvas">
#    <div class="inner-wrap">
#     <div class="personal" id="wrapper">
#      <noscript>
#       <div class="alert-box message msgWarning" data-alert="data-alert">
#        <code>
#         <span>
#          i
#         </span>
#        </code>
#        <p>
#         <span class="noindex">
#          Many features of this website require JavaScript to be enabled. Please enable JavaScript or expect some issues as you proceed.
#         </span>
#        </p>
#       </div>
#      </noscript>
#      <cpc-skip-nav class="cpc-component" data-skip-id="main-content">
#      </cpc-skip-nav>
#      <cpc-header class="cpc-component" data-app-id="inbox" data-current-page="tools" data-suppress-product-nav="true" data-suppress-toolbar="true">
#      </cpc-header>
#      <div id="contentWrap">
#       <div class="fpo">
#        <!-- DASHBANNER CONTAINER -->
#        <div id="dashBannerContainer">
#        </div>
#        <!-- PAGE CONTENT -->
#        <div id="accordion">
#         <div class="section" id="fpoGoogle">
#          <div class="row">
#           <div class="large-12 columns">
#            <h1 class="h1margintop60 nomargin_mobile">
#             Find a Post Office
#            </h1>
#            <h3 class="marginbottom60 margintop5_mobile marginbottom27_mobile">
#             We are closer than you think
#            </h3>
#           </div>
#          </div>
#          <div class="search-bar">
#           <div class="row">
#            <div class="small-8 medium-6 large-6 columns">
#             <label>
#              <span class="hidden">
#               Postal Code, Address, Intersection
#              </span>
#              <input id="g_address" onfocus="this.select();" type="text"/>
#             </label>
#            </div>
#            <div class="small-4 medium-6 large-6 no-padding-left columns">
#             <input class="button nomarginbottom margintop25" id="findPostOffice" onclick="codeAddressList(document.getElementById('g_address').value, 'personal');" type="submit" value="Go"/>
#            </div>
#           </div>
#           <div class="row">
#            <div class="large-12 columns">
#             <div class="alert-box message msgError hidden" data-alert="data-alert" id="g_errors">
#              <code>
#               <span>
#                ×
#               </span>
#              </code>
#              <p id="g_address_error">
#               We were not able to find any results.  Please check your entries and try again.
#              </p>
#             </div>
#            </div>
#           </div>
#          </div>
#          <!-- #END Search box -->
#         </div>
#        </div>
#       </div>
#       <div id="main">
#        <div class="row">
#         <div class="large-12 medium-12 columns">
#          <div class="row location-info negmargintop30">
#           <div class="large-12 columns">
#            <h5 id="location-results">
#             Location Nearest
#             <span class="address">
#             </span>
#            </h5>
#           </div>
#          </div>
#          <dl class="tabs" data-tab="data-tab" id="fpo-tabs">
#           <dd class="active" id="listTab" onclick="findPostOfficeList('personal'); return false;">
#            <a href="#">
#             List
#            </a>
#           </dd>
#           <dd id="mapTab" onclick="goToMap()">
#            <a href="#map">
#             Map
#            </a>
#           </dd>
#          </dl>
#          <hr class="large marginbottom20 show-for-medium-up"/>
#          <div class="tabs-content noBorder" id="resultContents">
#           <div class="content active">
#            <form action="/cpotools/apps/mc/app/personal/fpo/google/postOfficeListResult.xhtml" enctype="application/x-www-form-urlencoded" id="fpoListResultForm" method="post" name="fpoListResultForm">
#             <div id="results">
#              <ol>
#               <li>
#                <span class="hidden">
#                 1
#                </span>
#                TICKETS AND MORE
#                <br/>
#                1571 SANDHURST CIRCLE UNIT 161
#                <br/>
#                SCARBOROUGH ON   M1V 1V0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000104697">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 2
#                </span>
#                FINCH MIDLAND PHARMACY
#                <br/>
#                4190 FINCH AVE E
#                <br/>
#                SCARBOROUGH ON   M1S 4T0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000357693">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 3
#                </span>
#                MAIN DRUG MART
#                <br/>
#                1711 MCCOWAN RD
#                <br/>
#                SCARBOROUGH ON   M1S 2Y0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000266108">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 4
#                </span>
#                A AND W PHARMACY
#                <br/>
#                250 ALTON TOWERS CIR
#                <br/>
#                SCARBOROUGH ON   M1V 3Z0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000102108">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 5
#                </span>
#                SCARBOROUGH STN D
#                <br/>
#                280 PROGRESS AVE
#                <br/>
#                SCARBOROUGH ON   M1P 2Z0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000072354">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 6
#                </span>
#                REXALL DRUGSTORE #0919
#                <br/>
#                3607 SHEPPARD AVE E
#                <br/>
#                SCARBOROUGH ON   M1T 3L0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000075809">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 7
#                </span>
#                SHOPPERS DRUG MART #0860
#                <br/>
#                300 BOROUGH DR
#                <br/>
#                SCARBOROUGH ON   M1P 4P0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000251925">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 8
#                </span>
#                SHOPPERS DRUG MART #0875
#                <br/>
#                2355 WARDEN AVENUE
#                <br/>
#                SCARBOROUGH ON   M1T 1V0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000102524">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 9
#                </span>
#                SHOPPERS DRUG MART #0980
#                <br/>
#                2900 WARDEN AVE
#                <br/>
#                SCARBOROUGH ON   M1W 2S0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000056731">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 10
#                </span>
#                SHOPPERS DRUG MART #1314
#                <br/>
#                1235 MCCOWAN RD
#                <br/>
#                SCARBOROUGH ON   M1H 3K0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000103439">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 11
#                </span>
#                SHOPPERS DRUG MART #1301
#                <br/>
#                5671 STEELES AVE E
#                <br/>
#                SCARBOROUGH ON   M1V 5P0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000103574">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 12
#                </span>
#                MAC'S CONVENIENCE STORE #01019
#                <br/>
#                31 TAPSCOTT RD
#                <br/>
#                SCARBOROUGH ON   M1B 4Y0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000354716">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 13
#                </span>
#                SHOPPERS DRUG MART #0846
#                <br/>
#                1661 DENISON ST
#                <br/>
#                MARKHAM ON   L3R 6E0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000059382">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 14
#                </span>
#                GUARDIAN DRUGS
#                <br/>
#                2942 FINCH AVE E
#                <br/>
#                SCARBOROUGH ON   M1W 2T0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000266019">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 15
#                </span>
#                MAC'S CONVENIENCE STORE #00046
#                <br/>
#                1021 MARKHAM RD
#                <br/>
#                SCARBOROUGH ON   M1H 2Y0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000429902">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 16
#                </span>
#                SHOPPERS DRUG MART #1509
#                <br/>
#                2901 SHEPPARD AVE E
#                <br/>
#                SCARBOROUGH ON   M1T 3J0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000102498">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 17
#                </span>
#                SHOPPERS DRUG MART #0847
#                <br/>
#                7060 WARDEN AVE
#                <br/>
#                MARKHAM ON   L3R 5Y0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000103107">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 18
#                </span>
#                GREETINGS AND GIFTS
#                <br/>
#                4 - 2300 LAWRENCE AVE E
#                <br/>
#                TORONTO ON   M1P 2R0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000382779">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 19
#                </span>
#                SHOPPERS DRUG MART #0501
#                <br/>
#                685 MCCOWAN RD
#                <br/>
#                SCARBOROUGH ON   M1J 1J0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000097519">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 20
#                </span>
#                SHOPPERS DRUG MART #0851
#                <br/>
#                85 ELLESMERE RD
#                <br/>
#                SCARBOROUGH ON   M1R 4B0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000056448">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 21
#                </span>
#                MARKHAM STN INDUSTRIAL PARK
#                <br/>
#                3930 14TH AVE
#                <br/>
#                MARKHAM ON   L3R 3L0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000068063">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 22
#                </span>
#                SHOPPERS DRUG MART #1498
#                <br/>
#                BLDG A-1285 YORK MILLS RD
#                <br/>
#                DON MILLS ON   M3A 1Z0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000078565">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 23
#                </span>
#                SHOPPERS DRUG MART #0800
#                <br/>
#                629 MARKHAM RD
#                <br/>
#                SCARBOROUGH ON   M1H 2A0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000289752">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 24
#                </span>
#                SHOPPERS DRUG MART #1219
#                <br/>
#                7700 MARKHAM RD
#                <br/>
#                MARKHAM ON   L3S 4S0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000100801">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#               <li>
#                <span class="hidden">
#                 25
#                </span>
#                SHOPPERS DRUG MART #0830
#                <br/>
#                1800 SHEPPARD AVE E UNIT 2075
#                <br/>
#                NORTH YORK ON   M2J 5B0
#                <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
#                <br/>
#                Post Office
#                <p>
#                 <a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000102607">
#                  View details and directions
#                 </a>
#                </p>
#               </li>
#              </ol>
#             </div>
#             <input name="fpoListResultForm_SUBMIT" type="hidden" value="1"/>
#             <input name="autoScroll" type="hidden"/>
#            </form>
#           </div>
#          </div>
#          <div class="row">
#           <div class="large-12 medium-12 small-12 columns">
#            <ul class="large-block-grid-3 medium-block-grid-3 small-block-grid-1" data-equalizer="data-equalizer">
#             <li class="gutter twocolumnfix_tablet first" data-equalizer-watch="data-equalizer-watch">
#              <h4>
#               Buy supplies online
#              </h4>
#              <!--h6></h6-->
#              <p>
#               Order stamps, prepaid envelopes, shipping supplies and more.
#              </p>
#              <p>
#               <a href="/shop/shop.jsf?icid=ln12003724">
#                Shop now
#               </a>
#              </p>
#             </li>
#             <li class="gutter twocolumnfix_tablet" data-equalizer-watch="data-equalizer-watch">
#              <h4>
#               At the post office
#              </h4>
#              <!--h6>???fpoAddBox2SubTitle???</h6-->
#              <p>
#               Buy
#               <a href="/web/en/products/details.page?article=visa_and_phone_prepa">
#                Visa and phone prepaid cards
#               </a>
#               .
#              </p>
#              <p>
#               Buy and cash
#               <a href="/web/en/products/details.page?article=moneygram_and_postal">
#                postal Money Orders
#               </a>
#               .
#              </p>
#              <p>
#               Rent a
#               <a href="/web/en/products/details.page?article=postal_boxes">
#                postal box
#               </a>
#               .
#              </p>
#             </li>
#             <li class="gutter last add-spot">
#              <script language="JavaScript" type="text/javascript">
#               <!--
#
# //<![CDATA[
# if (typeof ord=='undefined') {ord=Math.random()*10000000000000000;}
# if (typeof(dfp_tile) == 'undefined') dfp_tile=1;
# document.write('<script language="JavaScript" src="https://ad.doubleclick.net/N9108/adj/canadapost.oao.en/apps/fpo;s1=apps;s2=fpo;pid=cpotools_apps_fpo_personal_findPostOffice;customer=personal;ptype=query;kw=;test=;capo=ad;pos=top;tile=' + (dfp_tile++) + ';sz=300x250;ord=' + ord + '?" type="text/javascript">
#              </script>
#              ');
# //]]&gt;
#
#
# //--&gt;
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
# <noscript>
#  <a href="https://ad.doubleclick.net/N9108/jump/canadapost.oao.en/apps/fpo;s1=apps;s2=fpo;pid=cpotools_apps_fpo_personal_findPostOffice;customer=personal;ptype=query;kw=;test=;capo=ad;pos=top;tile=2;sz=300x250;ord=123456789?">
#   <img border="0" height="250" src="https://ad.doubleclick.net/N9108/ad/canadapost.oao.en/apps/fpo;s1=apps;s2=fpo;pid=cpotools_apps_fpo_personal_findPostOffice;customer=personal;ptype=query;kw=;test=;capo=ad;pos=top;tile=2;sz=300x250;ord=123456789?" width="300"/>
#  </a>
# </noscript>
# <cpc-footer class="cpc-component">
# </cpc-footer>
# <div class="noindex">
# </div>
# <!-- Begin comScore Tag -->
# <script>
#  <!--
#
# 				/* <![CDATA[ */
# 				  var _comscore = _comscore || [];
# 				  _comscore.push({ c1: "2", c2: "6035946" });
# 				  (function() {
# 					var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# 					s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# 					el.parentNode.insertBefore(s, el);
# 				  })();
# 				  /* ]]> */
#
# //-->
# </script>
# <!-- End comScore Tag -->
# <script>
#  <!--
#
# 			//<![CDATA[
# 			var navIsBig = true;
# 			var $nav = $('.header-container');
# 			$( ".magnify-glass" ).click(function(e) {
# 			e.preventDefault();
# 			$(".magnify-glass").parent("li").toggleClass("arrow_box");
# 			$( ".search-container" ).slideToggle( "slow", function() {
# 			$(".search-container input").focus();
# 			});
# 			if(true) {
# 			$("body").animate({ paddingTop : ($(".magnify-glass").parent("li").hasClass("arrow_box")) ? "70px" : "-70px"}, "slow" );
# 			}
# 			return false;
# 			});
# 			$(function(){
# 			$(document).scroll( function() {
# 			var value = $(this).scrollTop();
# 			if ( value > 5 && navIsBig){
# 			$('#sitelinks').addClass('scroll');
# 			$('.top-bar-section ul.right').removeClass("top-bar-section-noscroll").addClass("top-bar-section-scroll");
# 			$nav.removeClass("header-container-noscroll").addClass("header-container-scroll");
# 			navIsBig = false;
# 			}
# 			else if (value <= 5 && !navIsBig) {
# 			var w = $(window).width();
# 			if (w >1024)  {
# 			$('#sitelinks').removeClass('scroll');
# 			$('.top-bar-section ul.right').removeClass("top-bar-section-scroll").addClass("top-bar-section-noscroll");
# 			$nav.removeClass("header-container-scroll").addClass("header-container-noscroll");
# 			navIsBig = true;
# 			}
# 			}
# 			});
# 			});
# 			//]]>
#
# //-->
# </script>
# <script src="/web/assets/js/foundation5/foundation.min.js">
#  <!--
#
# //-->
# </script>
# <script src="/web/assets/js/foundation5/vendor/foundation.equalizer.js">
#  <!--
#
# //-->
# </script>
# <script>
#  <!--
#
# 				$(document).foundation();
#
# //-->
# </script>
# <script type="text/javascript">
#  <!--
#
# 				  //<![CDATA[
#                   <!-- DTM Data Layer BEGIN -->
# 				  var on_a_tool = "tool";
#
# 				  digitalData.page = {
# 						 pageInfo:{
# 							   pageName: ("".length > 0 ? "" : "cpc.ca: > " + "en" + " > " + ("personal" == 'business' ? "business" : "common") + " > " + "fpo" + " > " + ("fpo" == 'miniform' || "fpo" == 'shop' ? (window.location.pathname.split('/').pop()).split(".")[0] + " > " : '') + "" + ("".length > 0 ? " > " : '') + "" + (on_a_tool.length > 0 ? on_a_tool : ($("form").length > 0 ? 'form' : 'thank you')))
# 						 },
# 						 category:{
# 							   primaryCategory: "fpo",
# 							   pageType: (on_a_tool.length > 0 ? on_a_tool : "page")
# 						 }
# 				  };
#
# 				  _satellite.track('Data Layer Ready');
# 				  <!-- DTM Data Layer END -->
# 				  //]]>
#
# //-->
# </script>
# <script type="text/javascript">
#  <!--
# _satellite.pageBottom();
# //-->
# </script>
# <!--
#     <c:catch var ="catchException">
#         <div class="serverName">a1p10d1-c1m2ms04</div>
#     </c:catch>
#     -->

# %% [markdown]
# ### Examine rendered webpage

# %%
#using the extension for BeautifulSoup to show syntax highlighting:
html_soup
# Out:
# C:\Users\andrew leung\AppData\Local\Continuum\Anaconda3\lib\site-packages\soup.py:64: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 64 of the file C:\Users\andrew leung\AppData\Local\Continuum\Anaconda3\lib\site-packages\soup.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   copy = BeautifulSoup(string_representation(soup))
# <!DOCTYPE html >
#
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="1AC9A4E083D8F5E10E160861745E4E0F" name="msvalidate.01"/>
# <meta content="36a5b4f0d2c3995c" name="y_key"/>
# <meta content="application/xhtml+xml, text/xml, text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="en-CA" http-equiv="content-language"/>
# <title>Canada Post - Find a Post Office - Results List</title>
# <meta content="post office, personal, postal outlet, post office Canada, find a post office, locate a post office, post office finder, locator, locations, hours, hours of operation, postal outlet, postal outlets, post office locations" http-equiv="keywords"/>
# <meta content="Find a post office near you using our online tool. Enter your address or postal code and get nearby post offices, outlets, maps and hours." http-equiv="description"/><meta content="Canada Post" name="categories"/><meta content="Post office locator, find nearest post office and post office hours" name="pta"/>
# <meta content="minimum-scale=1.0, maximum-scale=1.0, width=device-width, user-scalable=no" name="viewport"/>
# <meta content="index, follow" name="robots"/><link href="/cpotools/apps/fpo/personal/findPostOffice" rel="canonical"/>
# <link href="/cpotools/mc/assets/images/structure/cpo.ico" rel="shortcut icon" type="image/x-icon"/>
# <script src="//assets.adobedtm.com/8555ef77443acd85ab4eb6b187cf7ed7fe0f79eb/satelliteLib-f2fc6f00da802a0747b6ffed3c12e3931bfca496.js"><!--
#
# //--></script>
# <script><!--
#
# 			digitalData={
#   page:{
#          pageInfo:{
# 			 audience: ("personal" == 'business' ? "business" : "common"),
# 			 language: "en",
# 			 domain: document.location.host,
# 			 destinationURL: document.location.href,
# 			 destinationQueryString: document.location.search
# 		 },
#          category:{},
#          attributes: {
# 			channel:{
# 				site: document.location.host
# 			},
# 			externalCampaignID: "",
# 			internalCampaignID: "",
# 		    language: "en",
# 			internalSearch: {
# 				term: ""
# 			}
# 		},
#   },
#   event:[{
#          eventInfo:{}
#   }],
#   product:[{
#          productInfo:{}
#   }],
#   cart:{},
#   transaction:{
#          item:[{
#                productInfo:{},
#                price:{}
#          }],
#          profile:{
#                address:{}
#          },
#          total:{},
#          attributes:{}
#   },
#   user:[{
#          profile:[{
#                profileInfo:{},
#                attributes:{
#                       profileFAN:{}
#                }
#          }]
#   }]
# };
#
# //--></script>
# <link href="/web/assets/css/foundation5/normalize.css" rel="stylesheet"/>
# <link href="/web/assets/css/foundation5/foundation.min.css" rel="stylesheet"/>
# <link href="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.3/themes/smoothness/jquery-ui.css" rel="stylesheet"/>
# <link href="/web/assets/css/responsive.css" rel="stylesheet" type="text/css"/>
# <link href="/web/assets/css/vpo.css" rel="stylesheet" type="text/css"/>
# <link href="/cwc/components/assets/styles/cwc.css" rel="stylesheet" type="text/css"/>
# <link href="/web/assets/css/slick_slider.css" rel="stylesheet" type="text/css"/>
# <link href="/cpotools/mc/ui/css/extendstyles.css" rel="stylesheet" type="text/css"/>
# <link href="/cpotools/mc/ui/css/tony.css" rel="stylesheet" type="text/css"/>
# <link href="/cpotools/mc/ui/css/aaron.css" rel="stylesheet" type="text/css"/>
# <link href="/cpotools/mc/ui/css/kirk.css" rel="stylesheet" type="text/css"/>
# <link href="/cpotools/mc/ui/css/donald.css" rel="stylesheet" type="text/css"/>
# <link href="/cpotools/mc/ui/css/michael.css" rel="stylesheet" type="text/css"/>
# <!-- <link rel="stylesheet" type="text/css" href="/cpotools/mc/ui/css/2008_plus_styles.css" /> -->
# <link href="/cpotools/mc/ui/css/cp_print.css" media="print" rel="stylesheet" type="text/css"/>
# <link href="/cpotools/mc/ui/css/jquery.autocomplete.css" rel="stylesheet" type="text/css"/>
# <style><!--
#
#
#
# --></style>
# <link href="/mc/ui/css/kirk.css"/>
# <!--[if lt IE 9]><link rel="stylesheet" href="/web/assets/css/ie8-styles.css"/><![endif]-->
# <link href="https://fonts.googleapis.com/css?family=Roboto:400|Roboto:100|Roboto:100italic|Roboto:300|Roboto:300italic|Roboto:400italic|Roboto:500|Roboto:500italic|Roboto:700|Roboto:700italic|Roboto:900|Roboto:900italic" rel="stylesheet" type="text/css"/>
# <script language="javascript" type="text/javascript"><!--
#
#     // Global JS Vars - used in javascript functions
#     var GLOBALOBJ = new Object();
#     GLOBALOBJ.locale = "en";
#     GLOBALOBJ.style = 'STANDARD';
#     GLOBALOBJ.contextPath = "/cpotools";
#     GLOBALOBJ.baseSecuredApplicationUrl = "";
#
# //--></script>
# <script src="/web/assets/js/foundation5/vendor/modernizr.js"><!--
#
# //--></script>
# <script src="/web/assets/js/foundation5/vendor/jquery.js"><!--
#
# //--></script>
# <script src="/cwc/components/assets/scripts/cwc.js" type="text/javascript"><!--
#
# //--></script>
# <script src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.11.3/jquery-ui.min.js" type="text/javascript"><!--
#
# //--></script>
# <script src="/cpotools/mc/ui/js/selector.js" type="text/javascript"><!--
#
# //--></script>
# <script src="/cpotools/mc/ui/js/jquery-cookie.js" type="text/javascript"><!--
#
# //--></script>
# <script src="/cpotools/mc/ui/js/function.js" type="text/javascript"><!--
#
# //--></script>
# <script src="/cpotools/mc/ui/js/search_autocomplete.js" type="text/javascript"><!--
#
# //--></script>
# <script src="/web/assets/js/jCarousel.min.js" type="text/javascript"><!--
#
# //--></script>
# <script src="/cpotools/mc/ui/js/google-dfp.js" type="text/javascript"><!--
#
# //--></script>
# <script type="text/javascript"><!--
#
#       var inDash = "fpo";
#
# //--></script>
# <script type="text/javascript"><!--
#
#          var adops_lang = "en";
#          var adops_switch = "fpo";
#          var adops_test = "";
#      var adops_pageid = "D00017";
#
# //--></script>
# <script src="/web/assets/js/purl.js" type="text/javascript"><!--
#
# //--></script>
# <script src="/cpotools/mc/ui/js/adops_ts.js" type="text/javascript"><!--
#
# //--></script>
# <script src="/cpo/mc/ui/js/cpo.js" type="text/javascript"><!--
#
# //--></script>
# <script id="mapScript" language="javascript" type="text/javascript"><!--
# //<![CDATA[
# 			document.write('<scr' + 'ipt type="text/javascript" src="' + document.location.protocol + '//maps.googleapis.com/maps/api/js?v=3.7&sensor=false&language=' + 'en' + '&client=gme-innovapost1"></scr' + 'ipt>');
# 			//]]>
#
# //--></script>
# <script src="/cpotools/mc/ui/js/analytics/analyticsManager-min.js" type="text/javascript"><!--
#
# //--></script>
# <script src="/cpotools/mc/ui/js/google/gmaps.js" type="text/javascript"><!--
#
# //--></script>
# <script type="text/javascript"><!--
#
# 			$().ready(function()
# 			{
# 				loadLocation();
# 				document.getElementById("g_address").focus();
# 				$("#g_address").keyup(function(event){
# 					if(event.keyCode == 13){
# 						$("#findPostOffice").click();
# 					}
# 				});
#
# 				// Your location text
# 				var xResults = $("#g_address").val();
# 				$('#location-results .address').html(xResults);
# 			});
#
# 			// RQ9702
# 			function goToMap() {
# 				var value = gmapLocation.get("location");
# 				window.location='/cpotools/apps/fpo/personal/findPostOffice?location='+value;
# 			}
#
# 			// Web Analytics
#             analyticsData.pageID = 'postOfficeListResult';
#
#
# //--></script>
# <!-- SMART BANNERS:  -->
# <meta content="Canada Post Corporation" name="author"/>
# <meta content="app-id=394391577" name="apple-itunes-app"/>
# <meta content="app-id=com.canadapost.android" name="google-play-app"/>
# <link href="/web/assets/css/jquery.smartbanner.css" rel="stylesheet" type="text/css"/>
# <script src="/web/assets/js/jquery.smartbanner.js" type="text/javascript"><!--
#
# //--></script>
# <script type="text/javascript"><!--
#
# 		 $(function () {
#
# 		 	var language = "en";
#
# 		 	if(language == "en"){
# 		 		$.smartbanner({
# 		 		  title: "Canada Post Corporation",
# 		 		  author: "Canada Post",
# 		 		  price: 'FREE',
# 		 		  button: 'View',
# 		 		  scale: 'auto',
# 		 		  speedIn: 300,
# 		 		  speedOut: 400,
# 		 		  daysHidden: 0,
# 		 		  daysReminder: 0,
# 		 		  hideOnInstall: false,
# 		 		  layer: false,
# 		 		  force: null,
# 		 		  iOSUniversalApp: true,
# 		 		  appendToSelector: 'body'
# 		 		})
# 		 	}else{
# 		 		$.smartbanner({
# 		 		  title: "Société canadienne des postes",
# 		 		  author: "Postes Canada",
# 		 		  price: 'GRATUIT',
# 		 		  button: 'Afficher',
# 		 		  inAppStore: 'À partir de la boutique d\'applications',
# 		 		  inGooglePlay: 'Dans Google Play',
# 		 		  scale: 'auto',
# 		 		  speedIn: 300,
# 		 		  speedOut: 400,
# 		 		  daysHidden: 0,
# 		 		  daysReminder: 0,
# 		 		  hideOnInstall: false,
# 		 		  layer: false,
# 		 		  force: null,
# 		 		  iOSUniversalApp: true,
# 		 		  appendToSelector: 'body'
# 		 		})
#
# 		 	}
#
# 			if($("#topSiteMessageWrapper").length == 0) {
# 		 		$('#header').css('top','0');
# 			}
# 	 });
#
#
#
#
# //--></script>
# <!-- END OF SMART BANNERS:	 -->
# <!-- Twitter Code Start -->
# <script type="text/javascript"><!--
#
#       !function (e, t, n, s, u, a) {
#         e.twq || (s = e.twq = function () {
#           var _s;
#
#           s.exe ? (_s = s).exe.apply(_s, arguments) : s.queue.push(arguments);
#         }, s.version = '1.1', s.queue = [], u = t.createElement(n), u.async = !0, u.src = '//static.ads-twitter.com/uwt.js', a = t.getElementsByTagName(n)[0], a.parentNode.insertBefore(u, a));
#       }(window, document, 'script', 'https://static.ads-twitter.com/uwt.js');
#       // Insert Twitter Pixel ID and Standard Event data below
#       twq('init', 'ny0qm');
#       twq('track', 'PageView');
#
# //--></script>
# <!-- Twitter Code End  -->
# <!-- Facebook Pixel Code -->
# <script type="text/javascript"><!--
#
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#       if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#       n.queue=[];t=b.createElement(e);t.async=!0;
#       t.src=v;s=b.getElementsByTagName(e)[0];
#       s.parentNode.insertBefore(t,s)}(window,document,'script',
#         'https://connect.facebook.net/en_US/fbevents.js');
#       fbq('init', '786303741550354');
#       fbq('track', 'PageView');
#
# //--></script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=786303741550354&amp;ev=PageView&amp;noscript=1" width="1"/>
# </noscript>
# <!-- End Facebook Pixel Code -->
# </head>
# <!--[if IE 8]><body class="lt-ie9 en true wide"><![endif]-->
# <!--[if IE 9]><body class="lt-ie10 en true wide"><![endif]-->
# <!--[if gt IE 9]><!--><body class="en true wide"><!--<![endif]-->
# <!--BEGIN QUALTRICS SITE INTERCEPT-->
# <script type="text/javascript"><!--
#
# //<![CDATA[
# (function(){var g=function(e,h,f,g){
# this.get=function(a){for(var a=a+"=",c=document.cookie.split(";"),b=0,e=c.length;b<e;b++){for(var d=c[b];" "==d.charAt(0);)d=d.substring(1,d.length);if(0==d.indexOf(a))return d.substring(a.length,d.length)}return null};
# this.set=function(a,c){var b="",b=new Date;b.setTime(b.getTime()+6048E5);b="; expires="+b.toGMTString();document.cookie=a+"="+c+b+"; path=/; "};
# this.check=function(){var a=this.get(f);if(a)a=a.split(":");else if(100!=e)"v"==h&&(e=Math.random()>=e/100?0:100),a=[h,e,0],this.set(f,a.join(":"));else return!0;var c=a[1];if(100==c)return!0;switch(a[0]){case "v":return!1;case "r":return c=a[2]%Math.floor(100/c),a[2]++,this.set(f,a.join(":")),!c}return!0};
# this.go=function(){if(this.check()){var a=document.createElement("script");a.type="text/javascript";a.src=g+ "&t=" + (new Date()).getTime();document.body&&document.body.appendChild(a)}};
# this.start=function(){var a=this;window.addEventListener?window.addEventListener("load",function(){a.go()},!1):window.attachEvent&&window.attachEvent("onload",function(){a.go()})}};
# try{(new g(100,"r","QSI_S_ZN_0xleIR6sWSZaNY9","https://zn0xleir6swszany9-canadapostdigital.siteintercept.qualtrics.com/WRSiteInterceptEngine/?Q_ZID=ZN_0xleIR6sWSZaNY9&Q_LOC="+encodeURIComponent(window.location.href))).start()}catch(i){}})();
# //]]>
#
# //--></script><div id="ZN_0xleIR6sWSZaNY9"><!--DO NOT REMOVE-CONTENTS PLACED HERE--></div>
# <!--END SITE INTERCEPT-->
# <div class="" data-offcanvas="data-offcanvas">
# <div class="inner-wrap">
# <div class="personal" id="wrapper">
# <noscript>
# <div class="alert-box message msgWarning" data-alert="data-alert"> <code><span>i</span></code>
# <p><span class="noindex">Many features of this website require JavaScript to be enabled. Please enable JavaScript or expect some issues as you proceed.</span></p>
# </div>
# </noscript>
# <cpc-skip-nav class="cpc-component" data-skip-id="main-content"></cpc-skip-nav>
# <cpc-header class="cpc-component" data-app-id="inbox" data-current-page="tools" data-suppress-product-nav="true" data-suppress-toolbar="true"></cpc-header>
# <div id="contentWrap">
# <div class="fpo">
# <!-- DASHBANNER CONTAINER -->
# <div id="dashBannerContainer"></div>
# <!-- PAGE CONTENT -->
# <div id="accordion">
# <div class="section" id="fpoGoogle">
# <div class="row">
# <div class="large-12 columns">
# <h1 class="h1margintop60 nomargin_mobile">Find a Post Office</h1>
# <h3 class="marginbottom60 margintop5_mobile marginbottom27_mobile">We are closer than you think</h3>
# </div>
# </div>
# <div class="search-bar">
# <div class="row">
# <div class="small-8 medium-6 large-6 columns">
# <label><span class="hidden">Postal Code, Address, Intersection</span>
#                 <input id="g_address" onfocus="this.select();" type="text"/>
# </label>
# </div>
# <div class="small-4 medium-6 large-6 no-padding-left columns">
# <input class="button nomarginbottom margintop25" id="findPostOffice" onclick="codeAddressList(document.getElementById('g_address').value, 'personal');" type="submit" value="Go"/>
# </div>
# </div>
# <div class="row">
# <div class="large-12 columns">
# <div class="alert-box message msgError hidden" data-alert="data-alert" id="g_errors"> <code><span>×</span></code>
# <p id="g_address_error">We were not able to find any results.  Please check your entries and try again.</p>
# </div>
# </div>
# </div>
# </div>
# <!-- #END Search box -->
# </div>
# </div>
# </div>
# <div id="main">
# <div class="row">
# <div class="large-12 medium-12 columns">
# <div class="row location-info negmargintop30">
# <div class="large-12 columns">
# <h5 id="location-results">Location Nearest <span class="address"></span></h5>
# </div>
# </div>
# <dl class="tabs" data-tab="data-tab" id="fpo-tabs">
# <dd class="active" id="listTab" onclick="findPostOfficeList('personal'); return false;"><a href="#">List</a> </dd>
# <dd id="mapTab" onclick="goToMap()"><a href="#map">Map</a> </dd>
# </dl>
# <hr class="large marginbottom20 show-for-medium-up"/>
# <div class="tabs-content noBorder" id="resultContents">
# <div class="content active"><form action="/cpotools/apps/mc/app/personal/fpo/google/postOfficeListResult.xhtml" enctype="application/x-www-form-urlencoded" id="fpoListResultForm" method="post" name="fpoListResultForm">
# <div id="results">
# <ol>
# <li> <span class="hidden"> 1 </span>TICKETS AND MORE
#                   <br/>1571 SANDHURST CIRCLE UNIT 161
#                   <br/>SCARBOROUGH ON   M1V 1V0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000104697">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 2 </span>FINCH MIDLAND PHARMACY
#                   <br/>4190 FINCH AVE E
#                   <br/>SCARBOROUGH ON   M1S 4T0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000357693">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 3 </span>MAIN DRUG MART
#                   <br/>1711 MCCOWAN RD
#                   <br/>SCARBOROUGH ON   M1S 2Y0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000266108">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 4 </span>A AND W PHARMACY
#                   <br/>250 ALTON TOWERS CIR
#                   <br/>SCARBOROUGH ON   M1V 3Z0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000102108">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 5 </span>SCARBOROUGH STN D
#                   <br/>280 PROGRESS AVE
#                   <br/>SCARBOROUGH ON   M1P 2Z0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000072354">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 6 </span>REXALL DRUGSTORE #0919
#                   <br/>3607 SHEPPARD AVE E
#                   <br/>SCARBOROUGH ON   M1T 3L0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000075809">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 7 </span>SHOPPERS DRUG MART #0860
#                   <br/>300 BOROUGH DR
#                   <br/>SCARBOROUGH ON   M1P 4P0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000251925">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 8 </span>SHOPPERS DRUG MART #0875
#                   <br/>2355 WARDEN AVENUE
#                   <br/>SCARBOROUGH ON   M1T 1V0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000102524">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 9 </span>SHOPPERS DRUG MART #0980
#                   <br/>2900 WARDEN AVE
#                   <br/>SCARBOROUGH ON   M1W 2S0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000056731">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 10 </span>SHOPPERS DRUG MART #1314
#                   <br/>1235 MCCOWAN RD
#                   <br/>SCARBOROUGH ON   M1H 3K0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000103439">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 11 </span>SHOPPERS DRUG MART #1301
#                   <br/>5671 STEELES AVE E
#                   <br/>SCARBOROUGH ON   M1V 5P0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000103574">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 12 </span>MAC'S CONVENIENCE STORE #01019
#                   <br/>31 TAPSCOTT RD
#                   <br/>SCARBOROUGH ON   M1B 4Y0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000354716">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 13 </span>SHOPPERS DRUG MART #0846
#                   <br/>1661 DENISON ST
#                   <br/>MARKHAM ON   L3R 6E0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000059382">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 14 </span>GUARDIAN DRUGS
#                   <br/>2942 FINCH AVE E
#                   <br/>SCARBOROUGH ON   M1W 2T0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000266019">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 15 </span>MAC'S CONVENIENCE STORE #00046
#                   <br/>1021 MARKHAM RD
#                   <br/>SCARBOROUGH ON   M1H 2Y0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000429902">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 16 </span>SHOPPERS DRUG MART #1509
#                   <br/>2901 SHEPPARD AVE E
#                   <br/>SCARBOROUGH ON   M1T 3J0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000102498">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 17 </span>SHOPPERS DRUG MART #0847
#                   <br/>7060 WARDEN AVE
#                   <br/>MARKHAM ON   L3R 5Y0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000103107">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 18 </span>GREETINGS AND GIFTS
#                   <br/>4 - 2300 LAWRENCE AVE E
#                   <br/>TORONTO ON   M1P 2R0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000382779">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 19 </span>SHOPPERS DRUG MART #0501
#                   <br/>685 MCCOWAN RD
#                   <br/>SCARBOROUGH ON   M1J 1J0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000097519">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 20 </span>SHOPPERS DRUG MART #0851
#                   <br/>85 ELLESMERE RD
#                   <br/>SCARBOROUGH ON   M1R 4B0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000056448">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 21 </span>MARKHAM STN INDUSTRIAL PARK
#                   <br/>3930 14TH AVE
#                   <br/>MARKHAM ON   L3R 3L0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000068063">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 22 </span>SHOPPERS DRUG MART #1498
#                   <br/>BLDG A-1285 YORK MILLS RD
#                   <br/>DON MILLS ON   M3A 1Z0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000078565">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 23 </span>SHOPPERS DRUG MART #0800
#                   <br/>629 MARKHAM RD
#                   <br/>SCARBOROUGH ON   M1H 2A0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000289752">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 24 </span>SHOPPERS DRUG MART #1219
#                   <br/>7700 MARKHAM RD
#                   <br/>MARKHAM ON   L3S 4S0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000100801">View details and directions</a></p>
# </li>
# <li> <span class="hidden"> 25 </span>SHOPPERS DRUG MART #0830
#                   <br/>1800 SHEPPARD AVE E UNIT 2075
#                   <br/>NORTH YORK ON   M2J 5B0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000102607">View details and directions</a></p>
# </li>
# </ol>
# </div><input name="fpoListResultForm_SUBMIT" type="hidden" value="1"/><input name="autoScroll" type="hidden"/></form>
# </div>
# </div>
# <div class="row">
# <div class="large-12 medium-12 small-12 columns">
# <ul class="large-block-grid-3 medium-block-grid-3 small-block-grid-1" data-equalizer="data-equalizer">
# <li class="gutter twocolumnfix_tablet first" data-equalizer-watch="data-equalizer-watch">
# <h4>Buy supplies online</h4>
# <!--h6></h6-->
# <p>Order stamps, prepaid envelopes, shipping supplies and more.</p>
# <p><a href="/shop/shop.jsf?icid=ln12003724">Shop now</a></p>
# </li>
# <li class="gutter twocolumnfix_tablet" data-equalizer-watch="data-equalizer-watch">
# <h4>At the post office</h4>
# <!--h6>???fpoAddBox2SubTitle???</h6-->
# <p>Buy
#                 <a href="/web/en/products/details.page?article=visa_and_phone_prepa">Visa and phone prepaid cards</a>.</p>
# <p>Buy and cash
#                 <a href="/web/en/products/details.page?article=moneygram_and_postal">postal Money Orders</a>.</p>
# <p>Rent a
#                 <a href="/web/en/products/details.page?article=postal_boxes">postal box</a>.</p>
# </li>
# <li class="gutter last add-spot">
# <script language="JavaScript" type="text/javascript"><!--
#
# //<![CDATA[
# if (typeof ord=='undefined') {ord=Math.random()*10000000000000000;}
# if (typeof(dfp_tile) == 'undefined') dfp_tile=1;
# document.write('<script language="JavaScript" src="https://ad.doubleclick.net/N9108/adj/canadapost.oao.en/apps/fpo;s1=apps;s2=fpo;pid=cpotools_apps_fpo_personal_findPostOffice;customer=personal;ptype=query;kw=;test=;capo=ad;pos=top;tile=' + (dfp_tile++) + ';sz=300x250;ord=' + ord + '?" type="text/javascript"></script>');
# //]]&gt;
#
#
# //--&gt;</li></ul></div></div></div></div></div></div></div></div></div></body></html>
# <noscript><a href="https://ad.doubleclick.net/N9108/jump/canadapost.oao.en/apps/fpo;s1=apps;s2=fpo;pid=cpotools_apps_fpo_personal_findPostOffice;customer=personal;ptype=query;kw=;test=;capo=ad;pos=top;tile=2;sz=300x250;ord=123456789?"><img border="0" height="250" src="https://ad.doubleclick.net/N9108/ad/canadapost.oao.en/apps/fpo;s1=apps;s2=fpo;pid=cpotools_apps_fpo_personal_findPostOffice;customer=personal;ptype=query;kw=;test=;capo=ad;pos=top;tile=2;sz=300x250;ord=123456789?" width="300"/></a></noscript>
#
#
#
#
#
#
#
#
# <cpc-footer class="cpc-component"></cpc-footer>
#
#
#
# <div class="noindex">
# </div>
# <!-- Begin comScore Tag -->
# <script><!--
#
# 				/* <![CDATA[ */
# 				  var _comscore = _comscore || [];
# 				  _comscore.push({ c1: "2", c2: "6035946" });
# 				  (function() {
# 					var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
# 					s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
# 					el.parentNode.insertBefore(s, el);
# 				  })();
# 				  /* ]]> */
#
# //--></script>
# <!-- End comScore Tag -->
# <script><!--
#
# 			//<![CDATA[
# 			var navIsBig = true;
# 			var $nav = $('.header-container');
# 			$( ".magnify-glass" ).click(function(e) {
# 			e.preventDefault();
# 			$(".magnify-glass").parent("li").toggleClass("arrow_box");
# 			$( ".search-container" ).slideToggle( "slow", function() {
# 			$(".search-container input").focus();
# 			});
# 			if(true) {
# 			$("body").animate({ paddingTop : ($(".magnify-glass").parent("li").hasClass("arrow_box")) ? "70px" : "-70px"}, "slow" );
# 			}
# 			return false;
# 			});
# 			$(function(){
# 			$(document).scroll( function() {
# 			var value = $(this).scrollTop();
# 			if ( value > 5 && navIsBig){
# 			$('#sitelinks').addClass('scroll');
# 			$('.top-bar-section ul.right').removeClass("top-bar-section-noscroll").addClass("top-bar-section-scroll");
# 			$nav.removeClass("header-container-noscroll").addClass("header-container-scroll");
# 			navIsBig = false;
# 			}
# 			else if (value <= 5 && !navIsBig) {
# 			var w = $(window).width();
# 			if (w >1024)  {
# 			$('#sitelinks').removeClass('scroll');
# 			$('.top-bar-section ul.right').removeClass("top-bar-section-scroll").addClass("top-bar-section-noscroll");
# 			$nav.removeClass("header-container-scroll").addClass("header-container-noscroll");
# 			navIsBig = true;
# 			}
# 			}
# 			});
# 			});
# 			//]]>
#
# //--></script>
# <script src="/web/assets/js/foundation5/foundation.min.js"><!--
#
# //--></script>
# <script src="/web/assets/js/foundation5/vendor/foundation.equalizer.js"><!--
#
# //--></script>
# <script><!--
#
# 				$(document).foundation();
#
# //--></script>
# <script type="text/javascript"><!--
#
# 				  //<![CDATA[
#                   <!-- DTM Data Layer BEGIN -->
# 				  var on_a_tool = "tool";
#
# 				  digitalData.page = {
# 						 pageInfo:{
# 							   pageName: ("".length > 0 ? "" : "cpc.ca: > " + "en" + " > " + ("personal" == 'business' ? "business" : "common") + " > " + "fpo" + " > " + ("fpo" == 'miniform' || "fpo" == 'shop' ? (window.location.pathname.split('/').pop()).split(".")[0] + " > " : '') + "" + ("".length > 0 ? " > " : '') + "" + (on_a_tool.length > 0 ? on_a_tool : ($("form").length > 0 ? 'form' : 'thank you')))
# 						 },
# 						 category:{
# 							   primaryCategory: "fpo",
# 							   pageType: (on_a_tool.length > 0 ? on_a_tool : "page")
# 						 }
# 				  };
#
# 				  _satellite.track('Data Layer Ready');
# 				  <!-- DTM Data Layer END -->
# 				  //]]>
#
# //--></script>
# <script type="text/javascript"><!--
# _satellite.pageBottom();
# //--></script>
#
# <!--
#     <c:catch var ="catchException">
#         <div class="serverName">a1p10d1-c1m2ms04</div>
#     </c:catch>
#     -->

# %% [markdown]
# ## Identifying patterns and parsing necessary content

# %%
#find Post office name from "results" div first entry
post_name = html_soup.find('div', id="results").li.contents[2].strip()

# %%
#find Post office address from "results" div first entry
address = html_soup.find('div', id="results").li.contents[4].strip()

# %%
#find Post office City, PR and Postal Code from "results" div first entry
city_postal = html_soup.find('div', id="results").li.contents[6].strip().replace("\xa0", ",")

# %%
#Parse City and PR
city =city_postal[:-9].strip()

# %%
#Parse City
postal = city_postal[-8:].strip()

# %%
#create list to append arrays as dictionary
df_list=[]
df_list.append({'Post Office Name': post_name,
               'Address': address ,
               'City': city,
               'Postal Code': postal})

# %%
#create final dataframe with column names
df_out = pd.DataFrame(df_list, columns= ['Post Office Name','Address','City','Postal Code'])

# %%
#result
df_out
# Out:
#    Post Office Name                         Address            City  \
# 0  TICKETS AND MORE  1571 SANDHURST CIRCLE UNIT 161  SCARBOROUGH ON
#
#   Postal Code
# 0     M1V 1V0

# %%
#find all individual entries withing results div - contained within separate "li" tags
postal_results = html_soup.find('div', id="results").find_all('li')

# %%
#tests results with loop and counter

count = 0
for postal in postal_results:
    count+=1
    print(count, postal)
# Out:
# 1 <li> <span class="hidden"> 1 </span>TICKETS AND MORE
#                   <br/>1571 SANDHURST CIRCLE UNIT 161
#                   <br/>SCARBOROUGH ON   M1V 1V0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000104697">View details and directions</a></p>
# </li>
# 2 <li> <span class="hidden"> 2 </span>FINCH MIDLAND PHARMACY
#                   <br/>4190 FINCH AVE E
#                   <br/>SCARBOROUGH ON   M1S 4T0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000357693">View details and directions</a></p>
# </li>
# 3 <li> <span class="hidden"> 3 </span>MAIN DRUG MART
#                   <br/>1711 MCCOWAN RD
#                   <br/>SCARBOROUGH ON   M1S 2Y0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000266108">View details and directions</a></p>
# </li>
# 4 <li> <span class="hidden"> 4 </span>A AND W PHARMACY
#                   <br/>250 ALTON TOWERS CIR
#                   <br/>SCARBOROUGH ON   M1V 3Z0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000102108">View details and directions</a></p>
# </li>
# 5 <li> <span class="hidden"> 5 </span>SCARBOROUGH STN D
#                   <br/>280 PROGRESS AVE
#                   <br/>SCARBOROUGH ON   M1P 2Z0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000072354">View details and directions</a></p>
# </li>
# 6 <li> <span class="hidden"> 6 </span>REXALL DRUGSTORE #0919
#                   <br/>3607 SHEPPARD AVE E
#                   <br/>SCARBOROUGH ON   M1T 3L0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000075809">View details and directions</a></p>
# </li>
# 7 <li> <span class="hidden"> 7 </span>SHOPPERS DRUG MART #0860
#                   <br/>300 BOROUGH DR
#                   <br/>SCARBOROUGH ON   M1P 4P0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000251925">View details and directions</a></p>
# </li>
# 8 <li> <span class="hidden"> 8 </span>SHOPPERS DRUG MART #0875
#                   <br/>2355 WARDEN AVENUE
#                   <br/>SCARBOROUGH ON   M1T 1V0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000102524">View details and directions</a></p>
# </li>
# 9 <li> <span class="hidden"> 9 </span>SHOPPERS DRUG MART #0980
#                   <br/>2900 WARDEN AVE
#                   <br/>SCARBOROUGH ON   M1W 2S0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000056731">View details and directions</a></p>
# </li>
# 10 <li> <span class="hidden"> 10 </span>SHOPPERS DRUG MART #1314
#                   <br/>1235 MCCOWAN RD
#                   <br/>SCARBOROUGH ON   M1H 3K0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000103439">View details and directions</a></p>
# </li>
# 11 <li> <span class="hidden"> 11 </span>SHOPPERS DRUG MART #1301
#                   <br/>5671 STEELES AVE E
#                   <br/>SCARBOROUGH ON   M1V 5P0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000103574">View details and directions</a></p>
# </li>
# 12 <li> <span class="hidden"> 12 </span>MAC'S CONVENIENCE STORE #01019
#                   <br/>31 TAPSCOTT RD
#                   <br/>SCARBOROUGH ON   M1B 4Y0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000354716">View details and directions</a></p>
# </li>
# 13 <li> <span class="hidden"> 13 </span>SHOPPERS DRUG MART #0846
#                   <br/>1661 DENISON ST
#                   <br/>MARKHAM ON   L3R 6E0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000059382">View details and directions</a></p>
# </li>
# 14 <li> <span class="hidden"> 14 </span>GUARDIAN DRUGS
#                   <br/>2942 FINCH AVE E
#                   <br/>SCARBOROUGH ON   M1W 2T0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000266019">View details and directions</a></p>
# </li>
# 15 <li> <span class="hidden"> 15 </span>MAC'S CONVENIENCE STORE #00046
#                   <br/>1021 MARKHAM RD
#                   <br/>SCARBOROUGH ON   M1H 2Y0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000429902">View details and directions</a></p>
# </li>
# 16 <li> <span class="hidden"> 16 </span>SHOPPERS DRUG MART #1509
#                   <br/>2901 SHEPPARD AVE E
#                   <br/>SCARBOROUGH ON   M1T 3J0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000102498">View details and directions</a></p>
# </li>
# 17 <li> <span class="hidden"> 17 </span>SHOPPERS DRUG MART #0847
#                   <br/>7060 WARDEN AVE
#                   <br/>MARKHAM ON   L3R 5Y0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000103107">View details and directions</a></p>
# </li>
# 18 <li> <span class="hidden"> 18 </span>GREETINGS AND GIFTS
#                   <br/>4 - 2300 LAWRENCE AVE E
#                   <br/>TORONTO ON   M1P 2R0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000382779">View details and directions</a></p>
# </li>
# 19 <li> <span class="hidden"> 19 </span>SHOPPERS DRUG MART #0501
#                   <br/>685 MCCOWAN RD
#                   <br/>SCARBOROUGH ON   M1J 1J0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000097519">View details and directions</a></p>
# </li>
# 20 <li> <span class="hidden"> 20 </span>SHOPPERS DRUG MART #0851
#                   <br/>85 ELLESMERE RD
#                   <br/>SCARBOROUGH ON   M1R 4B0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000056448">View details and directions</a></p>
# </li>
# 21 <li> <span class="hidden"> 21 </span>MARKHAM STN INDUSTRIAL PARK
#                   <br/>3930 14TH AVE
#                   <br/>MARKHAM ON   L3R 3L0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000068063">View details and directions</a></p>
# </li>
# 22 <li> <span class="hidden"> 22 </span>SHOPPERS DRUG MART #1498
#                   <br/>BLDG A-1285 YORK MILLS RD
#                   <br/>DON MILLS ON   M3A 1Z0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000078565">View details and directions</a></p>
# </li>
# 23 <li> <span class="hidden"> 23 </span>SHOPPERS DRUG MART #0800
#                   <br/>629 MARKHAM RD
#                   <br/>SCARBOROUGH ON   M1H 2A0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000289752">View details and directions</a></p>
# </li>
# 24 <li> <span class="hidden"> 24 </span>SHOPPERS DRUG MART #1219
#                   <br/>7700 MARKHAM RD
#                   <br/>MARKHAM ON   L3S 4S0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000100801">View details and directions</a></p>
# </li>
# 25 <li> <span class="hidden"> 25 </span>SHOPPERS DRUG MART #0830
#                   <br/>1800 SHEPPARD AVE E UNIT 2075
#                   <br/>NORTH YORK ON   M2J 5B0
#                   <!--br/>
#                                     <h:outputText value="0.0 km"/>
#                                     <br/-->
# <br/>Post Office
#                   <p><a href="/cpotools/apps/fpo/personal/findPostOfficeDetail?outletId=0000102607">View details and directions</a></p>
# </li>

# %% [markdown]
# ## Final script and clean output table

# %%
#for loop to pull all results
df_list=[]

for postal in postal_results:
    post_name = postal.contents[2].strip()
    address = postal.contents[4].strip()
    city_postal = postal.contents[6].strip().replace("\xa0", ",")
    city =city_postal[:-9].strip()
    postal = city_postal[-8:].strip()
    #print(post_name)
    #print(address)
    #print(city_postal)
    #print(city)
    #print(postal)

    
    df_list.append({'Post Office Name': post_name,
               'Address': address ,
               'City': city,
               'Postal Code': postal})
   #print(df_list)
   #break

df_out = pd.DataFrame(df_list, columns= ['Post Office Name','Address','City','Postal Code'])

# %%
#final table with all PO boxes returned from query
df_out
# Out:
#                   Post Office Name                         Address  \
# 0                 TICKETS AND MORE  1571 SANDHURST CIRCLE UNIT 161
# 1           FINCH MIDLAND PHARMACY                4190 FINCH AVE E
# 2                   MAIN DRUG MART                 1711 MCCOWAN RD
# 3                 A AND W PHARMACY            250 ALTON TOWERS CIR
# 4                SCARBOROUGH STN D                280 PROGRESS AVE
# 5           REXALL DRUGSTORE #0919             3607 SHEPPARD AVE E
# 6         SHOPPERS DRUG MART #0860                  300 BOROUGH DR
# 7         SHOPPERS DRUG MART #0875              2355 WARDEN AVENUE
# 8         SHOPPERS DRUG MART #0980                 2900 WARDEN AVE
# 9         SHOPPERS DRUG MART #1314                 1235 MCCOWAN RD
# 10        SHOPPERS DRUG MART #1301              5671 STEELES AVE E
# 11  MAC'S CONVENIENCE STORE #01019                  31 TAPSCOTT RD
# 12        SHOPPERS DRUG MART #0846                 1661 DENISON ST
# 13                  GUARDIAN DRUGS                2942 FINCH AVE E
# 14  MAC'S CONVENIENCE STORE #00046                 1021 MARKHAM RD
# 15        SHOPPERS DRUG MART #1509             2901 SHEPPARD AVE E
# 16        SHOPPERS DRUG MART #0847                 7060 WARDEN AVE
# 17             GREETINGS AND GIFTS         4 - 2300 LAWRENCE AVE E
# 18        SHOPPERS DRUG MART #0501                  685 MCCOWAN RD
# 19        SHOPPERS DRUG MART #0851                 85 ELLESMERE RD
# 20     MARKHAM STN INDUSTRIAL PARK                   3930 14TH AVE
# 21        SHOPPERS DRUG MART #1498       BLDG A-1285 YORK MILLS RD
# 22        SHOPPERS DRUG MART #0800                  629 MARKHAM RD
# 23        SHOPPERS DRUG MART #1219                 7700 MARKHAM RD
# 24        SHOPPERS DRUG MART #0830   1800 SHEPPARD AVE E UNIT 2075
#
#               City Postal Code
# 0   SCARBOROUGH ON     M1V 1V0
# 1   SCARBOROUGH ON     M1S 4T0
# 2   SCARBOROUGH ON     M1S 2Y0
# 3   SCARBOROUGH ON     M1V 3Z0
# 4   SCARBOROUGH ON     M1P 2Z0
# 5   SCARBOROUGH ON     M1T 3L0
# 6   SCARBOROUGH ON     M1P 4P0
# 7   SCARBOROUGH ON     M1T 1V0
# 8   SCARBOROUGH ON     M1W 2S0
# 9   SCARBOROUGH ON     M1H 3K0
# 10  SCARBOROUGH ON     M1V 5P0
# 11  SCARBOROUGH ON     M1B 4Y0
# 12      MARKHAM ON     L3R 6E0
# 13  SCARBOROUGH ON     M1W 2T0
# 14  SCARBOROUGH ON     M1H 2Y0
# 15  SCARBOROUGH ON     M1T 3J0
# 16      MARKHAM ON     L3R 5Y0
# 17      TORONTO ON     M1P 2R0
# 18  SCARBOROUGH ON     M1J 1J0
# 19  SCARBOROUGH ON     M1R 4B0
# 20      MARKHAM ON     L3R 3L0
# 21    DON MILLS ON     M3A 1Z0
# 22  SCARBOROUGH ON     M1H 2A0
# 23      MARKHAM ON     L3S 4S0
# 24   NORTH YORK ON     M2J 5B0
